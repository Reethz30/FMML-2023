# %% [markdown]
# <a href="https://colab.research.google.com/github/Reethz30/FMML-2023/blob/colab/Module4_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FOUNDATIONS OF MODERN MACHINE LEARNING, IIIT Hyderabad
# # Module 4: Perceptron and Gradient Descent
# ## Lab 1: Perceptron
#
# In this lab, we will be studying the perceptron learning algorithm.

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# First we need to define a labeled data set. Let's make a toy dataset.

# %%
X = np.array([
    [-2, 4],
    [4, 1],
    [1, 6],
    [2, 4],
    [6, 2]
])

# %% [markdown]
# Next we need to add a bias term -1 into the data set.

# %%
X = np.array([
    [-2, 4, -1],
    [4, 1, -1],
    [1, 6, -1],
    [2, 4, -1],
    [6, 2, -1],
])

# %%
y = np.array([-1, -1, 1, 1, 1])

# %% [markdown]
# This small toy data set contains two samples labeled with −1 and three samples labeled with +1. This means we have a binary classification problem, as the data set contains two sample classes. Lets plot the dataset to see, that is is linearly seperable

# %%
for d, sample in enumerate(X):
    # Plot the negative samples
    if d < 2:
        plt.scatter(sample[0], sample[1], s=120, marker='_', linewidths=2)
    # Plot the positive samples
    else:
        plt.scatter(sample[0], sample[1], s=120, marker='+', linewidths=2)

# Print a possible hyperplane, that is seperating the two classes.
plt.plot([-2, 6], [6, 0.5])

# %% [markdown]
# Finally we can code our Perceptron algorithm using our update rule. To keep it simple, we will linearly loop over the sample set. For larger data sets it makes sence, to randomly pick a sample during each iteration in the for-loop.
#
# ![image.png](data:image/png;base64,...)
#
# The algorithm is shown in the above image.

# %%
def perceptron_algo(X, Y):
    w = np.zeros(len(X[0]))
    eta = 1
    epochs = 10

    for epoch in range(epochs):
        for i, x in enumerate(X):
            if (np.dot(X[i], w) * Y[i]) <= 0:
                w = w + eta * X[i] * Y[i]
    return w

# %%
def perceptron_algo_plot(X, Y):
    '''
    train perceptron and plot the total loss in each epoch.

    :param X: data samples
    :param Y: data labels
    :return: weight vector as a numpy array
    '''
    w = np.zeros(len(X[0]))
    eta = 1
    n = 30
    errors = []

    for t in range(n):
        total_error = 0
        for i, x in enumerate(X):
            if (np.dot(X[i], w) * Y[i]) <= 0:
                total_error += (np.dot(X[i], w) * Y[i])
                w = w + eta * X[i] * Y[i]
        errors.append(total_error * -1)

    plt.plot(errors)
    plt.xlabel('Epoch')
    plt.ylabel('Total Loss')

    return w

# %% [markdown]
# Next, we will see the the training error at each epoch.

# %%
w = perceptron_algo_plot(X, y)

# %% [markdown]
# We now plot the decision boundary and check which samples have been classified as positive and which samples have been classified as negative.

# %%
for d, sample in enumerate(X):
    # Plot the negative samples
    if d < 2:
        plt.scatter(sample[0], sample[1], s=120, marker='_', linewidths=2)
    # Plot the positive samples
    else:
        plt.scatter(sample[0], sample[1], s=120, marker='+', linewidths=2)

# Add our test samples

plt.scatter(2, 2, s=120, marker='_', linewidths=2, color='yellow')
plt.scatter(4, 3, s=120, marker='+', linewidths=2, color='blue')

# Print the hyperplane calculated by perceptron_sgd()
x2 = [w[0], w[1], -w[1], w[0]]
x3 = [w[0], w[1], w[1], -w[0]]

x2x3 = np.array([x2, x3])
X, Y, U, V = zip(*x2x3)
ax = plt.gca()
ax.quiver(X, Y, U, V, scale=1, color='blue')

# %% [markdown]
# As you can see, our algorithm has correctly classified all the samples. The decision boundary is shown in blue.

# %% [markdown]
# # Things to try
#
#
# 1.   Try this on a real dataset like the Sonar dataset or the Banknote Dataset and show the error plot.
# 2.   Increase/decrease the learning rate to see how many iterations will be take to coverge. Does it even converge on a huge learning rate?
# 4. Take a toy dataset that is not linearly separable and run the perceptron algorithm on it. What happens? Note your observations. An example is given below.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4344998c-9ce8-429f-97ff-943eaab58e0c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4344998c-9ce8-429f-97ff-943eaab58e0c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
bnd=pd.read_csv('BankNoteAuthentication.csv')

# %%
bnd.head()
# Out:
#    variance  skewness  curtosis  entropy  class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %%
from sklearn.model_selection import train_test_split
xdata=bnd.drop('class',axis = 1)
ydata=bnd['class']
X_train,X_test,Y_train, Y_test = train_test_split(xdata,ydata,test_size = 0.53,random_state = 23)

# %%
for d,i in enumerate(Y_train) :
  if i == 0 :
    plt.scatter(X_train['variance'].values[d],  X_train['skewness'].values[d], s= 120, marker = '_',linewidths = 2)
  else:
     plt.scatter(X_train['variance'].values[d],  X_train['skewness'].values[d], s= 120, marker = '+',linewidths = 2)

plt.plot([5.5,-3],[-15,15])

# %%
x=X_train.to_numpy()
y=Y_train.to_numpy()
perceptron_algo_plot(x,y)
# Out:
# array([-19.0697455, -14.46964  , -13.817647 , -12.492564 ])

# %%
for d,i in enumerate(Y_train) :
  if i == 0 :
    plt.scatter(X_train['variance'].values[d],  X_train['skewness'].values[d], s= 120, marker = '_',color = 'blue')
  else:
     plt.scatter(X_train['variance'].values[d],  X_train['skewness'].values[d], s= 120, marker = '+',color = 'red')

for d,i in enumerate(Y_test) :
  if i == 0 :
    plt.scatter(X_test['variance'].values[d],  X_test['skewness'].values[d], s= 120, marker = '_',color = 'pink')
  else:
     plt.scatter(X_test['variance'].values[d],  X_test['skewness'].values[d], s= 120, marker = '+', color = 'black')

# Print the hyperplane calculated by perceptron_sgd()
x2 = [w[0], w[1], -w[1], w[0]]
x3 = [w[0], w[1], w[1], -w[0]]

x2x3 = np.array([x2, x3])
X, Y, U, V = zip(*x2x3)
ax = plt.gca()
ax.quiver(X, Y, U, V, scale=1, color='blue')

# %%
X = np.array([
    [-2, 4, -1],
    [4, 1, -1],
    [1, 6, -1],
    [2, 4, -1],
    [6, 2, -1],
])
y = np.array([-1, -1, 1, 1, 1])
perceptron_algo_plot(X,y)
# Out:
# array([ 2.,  3., 13.])

# %%
y = np.array([-1, -1, 1, 1, 1])

# %%
def perceptron_algo_plot1(X, Y,k,colour):
    w=np.zeros(len(X[0]))
    eta=k
    n=20
    errors = []

    for t in range(n):
        total_error = 0
        for i, x in enumerate(X):
            if (np.dot(X[i], w) * Y[i]) <= 0:
                total_error += (np.dot(X[i], w) * Y[i])
                w = w + eta * X[i] * Y[i]
        errors.append(total_error * -1)

    plt.plot(errors,color = colour)
    plt.xlabel('Epoch')
    plt.ylabel('Total Loss')

    return w

# %%
perceptron_algo_plot1(X,y,0,'yellow')
# Out:
# array([0., 0., 0.])

# %%
perceptron_algo_plot1(X,y,0.1,'purple')
# Out:
# array([0.2, 0.3, 1.3])

# %%
perceptron_algo_plot1(X,y,0.3,'blue')
# Out:
# array([0.6, 0.9, 3.9])

# %%
perceptron_algo_plot1(X,y,0.8,'orange')
# Out:
# array([ 1.6,  2.4, 10.4])

# %%
perceptron_algo_plot1(X,y,1,'pink')
# Out:
# array([ 2.,  3., 13.])

# %%
y1 = np.array([-1, 1, 1, 1, -1])
print(perceptron_algo_plot(X, y1))
# Out:
# [-3.  4.  6.]

# %%
perceptron_algo_plot1(X,y1,0.2,'red')
# Out:
# array([-0.6, -0.2,  1. ])

# %%
perceptron_algo_plot1(X,y1,0.6,'orange')
# Out:
# array([-1.8, -0.6,  3. ])

# %%
perceptron_algo_plot1(X,y1,1,'green')
# Out:
# array([-3., -1.,  5.])

# %%
y2 = np.array([-1, -1, 1, -1, -1])

# %%
print(perceptron_algo_plot(X, y2))
# Out:
# [-2.  3. 15.]

# %%
perceptron_algo_plot1(X,y2,0.2,'red')
# Out:
# array([-0.4,  0.6,  2. ])

# %%
perceptron_algo_plot1(X,y2,0.6,'orange')
# Out:
# array([-1.2,  1.8,  6. ])

# %%
perceptron_algo_plot1(X,y2,1,'green')
# Out:
# array([-2.,  3., 10.])

# %% [markdown]
# If the training data is not Linearly Separable, the perceptron algorithm will eventually repeat the same set of weights and thereby enter an infinite loop.
